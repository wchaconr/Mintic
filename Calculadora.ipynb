# %% [markdown]
# <a href="https://colab.research.google.com/github/wchaconr/Mintic/blob/main/Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 2.4
#
# *Elaborado por Oscar Franco-Bedoya*
#
# *`Proyecto Misión TIC 2022*
#
#
# ## Objetivo
# En este laboratorio vamos a unificar todos los conceptos sobre programación que hemos visto esta semana, incluyendo:
# *   Variables
# *   Tipos de datos
# *   Entrada y salida
# *   Funciones
#   * Retorno de valores
#   * Parametros
# *   Modulo principal
#
# Todos ellos aplicando el proceso IDEAL
#
# ## La tienda de la esquina
# ### Contexto
# En la tienda “de la esquina” su administrador dueño y gerente don Jose Esquina, desea un programa que le permita realizar las 4 operaciones aritméticas básicas (i.e., suma, resta, multiplicación y división) el asegura que son las únicas que necesita para controlar sus ventas y que a pesar de que siempre lo ha hecho mentalmente, los años están haciendo mella en él y necesita apoyo de la tecnología.
#
# Para probar si podemos cumplir con sus requisitos por ahora solo desea un programa que haga las 4 operaciones aritméticas para un par de números reales, y que muestre el resultado de cada una en órden:
#
# 1.   Suma
# 2.   Resta
# 3.   Multiplicación
# 4.   División
#
# ###Identificar el problema
# **¿Cuál es el problema/objetivo?**
#
# Don José tiene problemas para realizar las cuentas de su tienda
#
# **¿Quiénes son los interesados?**
# *   (cliente) Don José
# *   (usuario) Don José
# **¿Cuál es el objetivo?**
# *   Realizar las 4 operaciones aritméticas
# **¿Se tienen restricciones?**
# *   No
#
# ### Definir el problema
# **¿Qué información conozco (que nos dan)?**
# *   Se dan dos números reales
# *   Las 4 operaciones aritméticas
#
#
# **¿Qué información debo conocer (para lograr el objetivo)?**
# *  Los dos numeros reales
# *  Los operadores para las 4 operaciones aritméticas
#
# **Dividir el problema en subproblemas**
# *   Solicitar los dos numeros reales
# *   Calcular la suma de los dos números
# *   Calcular la resta de los dos números
# *   Calcular la multiplicación entre los dos números
# *   Calcular la división  entre los dos números
#
# ### Estrategia
# **Ejemplos particulares**
#
# numero uno = 20.0
# numero dos = 10.0
#
# *  suma = 20.0 + 10.0 (30.0)
# *  resta = 20.0 - 10.0 (10.0)
# *  multiplicación = 20.0 * 10.0 (200.0)
# *  división = 20.0 / 10.0 (2.0)
#
# **Estrategia de solución**
# 1.  Leer los dos numeros
# 2.  Realizar en el órden especificado las 4 operaciones y  mostrar cada resultado
# ### Algoritmos
# **Requisitos de software**
#
# ---
# **Algoritmo:** sumar dos numeros
# ---
#
# ***Parametros:***  numero_uno, numero_dos
# 1.  suma = numero_uno + numero_dos
# 2.  **Retornar** suma
# ----
# **Algoritmo:** restar dos numeros
#
# ***Parametros:***  numero_uno, numero_dos
# 1.  resta = numero_uno - numero_dos
# 2.  **Retornar** resta
# ----
# ----
# **Algoritmo:** multiplicar dos numeros
#
# ***Parametros:***  numero_uno, numero_dos
# 1.  multiplicacion = numero_uno * numero_dos
# 2.  **Retornar** multiplicacion
# ----
# ----
# **Algoritmo:** dividir dos numeros
#
# ***Parametros:***  numero_uno, numero_dos
# 1.  division = numero_uno / numero_dos
# 2.  **Retornar** division
# ----
#
# ### Logros
# Implementar los algoritmos en Python

# %%
""" Laboratorio 1.3 La tienda de a esquina #
    Oscar Franco-Bedoya
    Mayo 3-2021 """
# Definición de Funciones
def sumar_numeros(numero_uno, numero_dos):
  """ 
  Parameters
  ----------
  numero_uno:float
     operando uno para la suma
  numero_dos:float
     operando dos para la suma
  Returns
  -------
  suma:float
    el resultado de la suma     
  """  
  suma= numero_uno+numero_dos
  return suma

# completa las demás operaciones
def restar_numeros(numero_uno, numero_dos):
  #completa el código que falta
  resta= numero_uno-numero_dos
  return resta 

def multiplicar_numeros(numero_uno, numero_dos):
  #completa el código que falta
  multiplicacion= numero_uno*numero_dos
  return multiplicacion

def dividir_numeros(numero_uno, numero_dos):
  #completa el código que falta
  division= numero_uno/numero_dos
  return division

# --------------------------

# Conquistar: Programa principal
numero_uno=float(input("Digite el numero 1:"))
numero_dos=float(input("Digite el numero 2:"))

resultado_suma = sumar_numeros(numero_uno, numero_dos)
resultado_resta = restar_numeros(numero_uno, numero_dos)
resultado_multiplicacion = multiplicar_numeros(numero_uno, numero_dos)
resultado_division = dividir_numeros(numero_uno, numero_dos)

# Escribir los resultados
#completa el código que falta

print('La suma de los dos valores es:', resultado_suma) 
print('La resta de los dos valores es:', resultado_resta)
print('La multiplicación de los dos valores2 es:', resultado_multiplicacion)
print('La división de los dos valores es:', resultado_division)
# Out:
# Digite el numero 1:10
# Digite el numero 2:2
# La suma de los dos valores es: 12.0
# La resta de los dos valores es: 8.0
# La multiplicación de los dos valores2 es: 20.0
# La división de los dos valores es: 5.0

# %% [markdown]
# # ¿Sin errores?
# Que el intérprete de Python nos indique que nuestro código fuente no tiene errores sintácticos es un gran paso. Sin embargo debemos validar que al ejecutarlo realmente calcule los resultados esperados para las entradas dadas.
#
# Una técnica muy fácil es hacer **pruebas manuales** del software, es decir dar algunos casos particulares de ejemplo (¿Especialización recuerdas?) para ver si el programa retorna los valores que esperamos.
#
# ### Casos de prueba para el ejercicio de calculadora
# Prueba tu programa para ver si obtiene los resultados esperados
#
#
#
# | numero_uno |numero_dos | Suma | Resta | Multiplicación| División |
# | :---: | :---: | :---: |  :---: | :---: |  :---: |
# | 100 | 20 | 120 | 80 | 2000 | 5 |
# | 20 | 100 | 120 | -80 | 2000 | 05 |
# | 10 | 3 | 13 | 7 | 30 | 3.33 |
# | 0 | 0 | 0 | 0 | 0 | ? |
# | 0 | 20 | 20 | -20 | 0 | 0 |
# | -100 | -20 | -120 | -80 | 2000 | 5 |
#
# ---
#
# FINAL TALLER
#
# ---
